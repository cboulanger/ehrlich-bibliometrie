# %%
from scripts.dnb_data import compare_persons, plot_comparison
persons = ['Ehrlich Eugen', 'Marx Karl', 'Weber Max', 'Luhmann Niklas']
yearly_counts = compare_persons(persons, 1960, 2023)
plot_comparison(yearly_counts, lang="de", filename="01-dnb-ehrlich-marx-weber-luhmann.png")

# %%
from scripts.dnb_data import compare_persons, plot_comparison
persons = ['Ehrlich Eugen']
yearly_counts = compare_persons(persons, 1960, 2023)
yearly_counts
# Out:
# defaultdict(<function scripts.dnb_data.compare_persons.<locals>.<lambda>()>,
#             {'Ehrlich Eugen': defaultdict(int,
#                          {'2022': 2,
#                           '2021': 1,
#                           '2020': 2,
#                           '2019': 1,
#                           '2017': 1,
#                           '2014': 3,
#                           '2013': 3,
#                           '2011': 2,
#                           '2010': 1,
#                           '2008': 1,
#                           '2007': 1,
#                           '2005': 1,
#                           '2003': 1,
#                           '2001': 1,
#                           '1999': 1,
#                           '1992': 1,
#                           '1989': 1,
#                           '1987': 1,
#                           '1986': 3,
#                           '1981': 1,
#                           '1976': 1,
#                           '1973': 2,
#                           '1970': 3,
#                           '1967': 2,
#                           '1966': 1,
#                           '1962': 1})})
